# %% [markdown]
# ## Unit 1 - Python Basics
# ### Session 3: Python Control Statements & Python Strings
#
# ### Nested Loops

# %% [markdown]
# ### Pattern 1
#
# 1<br>
# 12<br>
# 123<br>
# 1234<br>
# 12345<br>

# %% [markdown]
# # Loop Control Statement
#
# - Break
# - Continue
# - Pass

# %%
#Break

# %%
# Continue

# %%
# Pass

# %% [markdown]
# Strings are sequence of Characters
#
# In Python specifically, strings are a sequence of Unicode Characters
#
# - Creating Strings
# - Accessing Strings
# - Adding Chars to Strings
# - Editing Strings
# - Deleting Strings
# - Operations on Strings
# - String Functions

# %% [markdown]
# ## Creating Stings

# %%
strategy_name =  "Momentum strategy"
strategy_name_latest = strategy_name + " latest"
strategy_name_latest
del strategy_name

# %%
strategy_name

# %% [markdown]
# ## Accessing Substrings from a String

# %%
# Positive Indexing

# %%
# Negative Indexing

# %%
# Slicing

# %% [markdown]
# ## Editing and Deleting in Strings

# %%
# Python strings are immutable

# %%
s = 'Momentum Strategy'
del s
print(s)

# %% [markdown]
# ## Operations on Strings
#
# - Arithmetic Operations
# - Relational Operations
# - Logical Operations
# - Loops on Strings
# - Membership Operations

# %%
s1 = "Singapore"
s2 = "India"
f = s1 +  " " + s2
sorted(f)
# Out:
# [' ', 'I', 'S', 'a', 'a', 'd', 'e', 'g', 'i', 'i', 'n', 'n', 'o', 'p', 'r']

# %%
(s1 + " ")*5

# %%
s1 > s2

# %%
s1 = ""
s2 = "India"

"x" in s2

# %% [markdown]
# ## Common Functions
# - len
# - max
# - min
# - sorted

# %%
s1 = "Singapore"
s2 = "India"
sorted(s1)
# Out:
# ['S', 'a', 'e', 'g', 'i', 'n', 'o', 'p', 'r']

# %% [markdown]
# ## Capitalize/Title/Upper/Lower/Swapcase

# %%
s1 = "Singapore"
s2 = "India"
f = s1 + " " + s2
s1.capitalize()
# Out:
# 'Singapore'

# %%
f.swapcase()
# Out:
# 'sINGAPORE iNDIA'

# %% [markdown]
# ## Count/Find/Index

# %%
s1 = "Singapore"
s2 = "India"
f = s1 + " " + s2
f
# Out:
# 'Singapore India'

# %%
f.index('s')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 f.index('s')
#
# ValueError: substring not found

# %% [markdown]
# ## endswith/startswith

# %%
s1 = "Singapore"
s2 = "India"
f = s1 + " " + s2
f
# Out:
# 'Singapore India'

# %%
f.startswith('S')
# Out:
# True

# %% [markdown]
# ## format

# %%
s1 = "Singapore"
s2 = "India"
f = s1 + " " + s2
f
print("Hello world this is Kuldeep and i am from {} and currently i am working in {}".format(s2,s1))
# Out:
# Hello world this is Kuldeep and i am from India and currently i am working in Singapore

# %% [markdown]
# ## isalnum/ isalpha/ isdigit/ isidentifier

# %%
s1 = "Singapore123"
s2 = "India"
s3 = "123"

f = s1 + " " + s2
f
# Out:
# 'Singapore123 India'

# %%
s1.isalnum()
# Out:
# True

# %%
s2.isdigit()
# Out:
# False

# %%
s3.isalpha()
# Out:
# False

# %% [markdown]
# ## Split/Join

# %%
s1 = "Singapore"
s2 = "India"
s3 = "123"
f = s1 + " " + s2 + " " + s3
f
# Out:
# 'Singapore India 123'

# %%
f.split("i")
# Out:
# ['S', 'ngapore Ind', 'a 123']

# %%
['S', 'ngapore Ind', 'a 123']

" ".join(['S', 'ngapore Ind', 'a 123'])
# Out:
# 'S ngapore Ind a 123'

# %% [markdown]
# ## Replace

# %%
s1 = "     Singapore    "
s2 = "     India       "
s3 = "     123                               "
f = s1 + " " + s2 + " " + s3
f
# Out:
# '     Singapore          India             123                               '

# %%
f.replace("123","are really close friends")
# Out:
# 'Singapore India are really close friends'

# %% [markdown]
# ## Strip

# %%
s1.strip()
# Out:
# 'Singapore'

# %% [markdown]
# ## Example Programs

# %%
# Write a program which can remove a particular character from a string.
s = input('enter the string')
term = input('what would like to remove')

result = ''

for i in s:
  if i != term:
    result = result + i

print(result)

# %%
# Write a program that can check whether a given string is palindrome or not.
# abba
# malayalam

s = input('enter the string')
flag = True
for i in range(0,len(s)//2):
  if s[i] != s[len(s) - i -1]:
    flag = False
    print('Not a Palindrome')
    break

if flag:
  print('Palindrome')

# %%
# Write a program to count the number of words in a string without split()

s = input('enter the string')
L = []
temp = ''
for i in s:

  if i != ' ':
    temp = temp + i
  else:
    L.append(temp)
    temp = ''

L.append(temp)
print(L)

# %%
# Write a python program to convert a string to title case without using the title()
s = input('enter the string')

L = []
for i in s.split():
  L.append(i[0].upper() + i[1:].lower())

print(" ".join(L))

# %%
# Write a program that can convert an integer to string.

number = int(input('enter the number'))

digits = '0123456789'
result = ''
while number != 0:
  result = digits[number % 10] + result
  number = number//10

print(result)
print(type(result))
