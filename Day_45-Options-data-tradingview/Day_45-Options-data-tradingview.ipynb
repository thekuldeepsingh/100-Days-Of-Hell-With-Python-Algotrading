# %%
from tvDatafeed import TvDatafeed, Interval

# username = 'YourTradingViewUsername'
# password = 'YourTradingViewPassword'

tv = TvDatafeed()
# Out:
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited

# %%
# index
bitcoin_data = tv.get_hist(symbol='BANKNIFTY1!',exchange='NSE',interval=Interval.in_1_hour,n_bars=1000)

# # futures continuous contract
# nifty_futures_data = tv.get_hist(symbol='NIFTY',exchange='NSE',interval=Interval.in_1_hour,n_bars=1000,fut_contract=1)

# # crudeoil
# crudeoil_data = tv.get_hist(symbol='CRUDEOIL',exchange='MCX',interval=Interval.in_1_hour,n_bars=5000,fut_contract=1)

# # downloading data for extended market hours
# extended_price_data = tv.get_hist(symbol="EICHERMOT",exchange="NSE",interval=Interval.in_1_hour,n_bars=500, extended_session=False)

# %%
bitcoin_data
# Out:
#                               symbol      open      high       low     close  \
# datetime
# 2023-12-14 11:45:00  NSE:BANKNIFTY1!  47652.20  48199.95  47650.30  48103.45
# 2023-12-14 12:45:00  NSE:BANKNIFTY1!  48117.10  48117.10  47934.10  48035.00
# 2023-12-14 13:45:00  NSE:BANKNIFTY1!  48030.35  48059.15  47945.00  47980.45
# 2023-12-14 14:45:00  NSE:BANKNIFTY1!  47980.15  48094.15  47950.00  48057.65
# 2023-12-14 15:45:00  NSE:BANKNIFTY1!  48058.50  48115.00  48000.00  48050.00
# ...                              ...       ...       ...       ...       ...
# 2024-07-12 13:45:00  NSE:BANKNIFTY1!  52686.80  52698.80  52505.00  52625.00
# 2024-07-12 14:45:00  NSE:BANKNIFTY1!  52630.00  52650.00  52535.10  52629.85
# 2024-07-12 15:45:00  NSE:BANKNIFTY1!  52628.60  52698.00  52601.25  52640.00
# 2024-07-12 16:45:00  NSE:BANKNIFTY1!  52640.00  52665.95  52303.95  52303.95
# 2024-07-12 17:45:00  NSE:BANKNIFTY1!  52311.20  52401.00  52270.00  52397.25
#
#                         volume
# datetime
# 2023-12-14 11:45:00  1139190.0
# 2023-12-14 12:45:00   278835.0
# 2023-12-14 13:45:00   127290.0
# 2023-12-14 14:45:00   115860.0
# 2023-12-14 15:45:00   165300.0
# ...                        ...
# 2024-07-12 13:45:00   236805.0
# 2024-07-12 14:45:00    96060.0
# 2024-07-12 15:45:00   130185.0
# 2024-07-12 16:45:00   402645.0
# 2024-07-12 17:45:00   199845.0
#
# [1000 rows x 6 columns]

# %%
bitcoin_data['close'].rolling(20).mean()
